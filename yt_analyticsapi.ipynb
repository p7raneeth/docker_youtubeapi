# %%
import googleapiclient.discovery
import os

# %%
os.environ['OATHLIB_INSECURE_TRANSPORT'] = "1"
api_service_name, api_version, DEVELOPER_KEY = "youtube", "v3", "AIzaSyDs6CAMKo4YaEfT0G9X1l2ZsS42cLndPYA"

# %%
api_service_name
# Out:
# 'youtube'

# %%
yt = googleapiclient.discovery.build(api_service_name, api_version, developerKey = dev_key)

# %%
vr = yt.commonThreads().list(part='snippet,id',  id="jVUUJ2eMDKc")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-886b01fdc36f> in <module>
# ----> 1 vr = yt.commonThreads().list(part='snippet,id',  id="jVUUJ2eMDKc")
#
# AttributeError: 'Resource' object has no attribute 'commonThreads'

# %%
vr.execute()
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'NYWOERe3V404U2-PQtHmEY4tozY',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'VPAudmhX24rcQ7DkzDjxE2hIOXk',
#    'id': 'jVUUJ2eMDKc',
#    'snippet': {'publishedAt': '2022-07-21T07:26:32Z',
#     'channelId': 'UCkw4JCwteGrDHIsyIIKo4tQ',
#     'title': 'Cloud Engineer Roles and Responsibilities | Cloud Engineer Certification| Edureka Rewind -1',
# ...

# %%
os.environ["OAUTHLIB_INSECURE_TRANSPORT"] = "1"

api_service_name = "youtube"
api_version = "v3"
# DEVELOPER_KEY = "YOUR_API_KEY"

youtube = googleapiclient.discovery.build(
    api_service_name, api_version, developerKey = DEVELOPER_KEY)

request = youtube.commentThreads().list(
    part="snippet,replies",
    videoId="_VB39Jo8mAQ"
)

# %%
request.execute()
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'Zp6aPrDG-MgIatO8Q3nNUVHHYEQ',
#  'nextPageToken': 'QURTSl9pMzV5MDFockUyWXVpRWhhRXlkZ2JjSWRkMUZPWnBEQTlFdXQ1TEN5WmJldzZIeEV1aFg5LVdZaDRuNHFwLUV2aFFiYXg2NDY0RQ==',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'f91NXz4HzKlm14zvNMRGBO5Aq2E',
#    'id': 'UgyAOWhZ9esp5acCFNB4AaABAg',
#    'snippet': {'videoId': '_VB39Jo8mAQ',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'ez4nUZCUJ13EOtd3_rMLZLUmRkQ',
#      'id': 'UgyAOWhZ9esp5acCFNB4AaABAg',
#      'snippet': {'videoId': '_VB39Jo8mAQ',
#       'textDisplay': 'Is that supposed to be a scientific approach? Based on a dataset of N=3? How many of any of these claims are actually backed up by studies?',
#       'textOriginal': 'Is that supposed to be a scientific approach? Based on a dataset of N=3? How many of any of these claims are actually backed up by studies?',
# ...

# %%
flow = google_auth_oauthlib.flow.InstalledAppFlow.from_client_secrets_file(
    client_secrets_file, scopes)
credentials = flow.run_console()
youtube = googleapiclient.discovery.build(
    api_service_name, api_version, credentials=credentials)

request = youtube.i18nRegions().list(

)
response = request.execute()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-6096597f98b7> in <module>
# ----> 1 flow = google_auth_oauthlib.flow.InstalledAppFlow.from_client_secrets_file(
#       2     client_secrets_file, scopes)
#       3 credentials = flow.run_console()
#       4 youtube = googleapiclient.discovery.build(
#       5     api_service_name, api_version, credentials=credentials)
#
# NameError: name 'google_auth_oauthlib' is not defined

# %%
# youtube analytics

# %%
import os
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow

# %%
SCOPES = ['https://www.googleapis.com/auth/yt-analytics.readonly']

# %%
API_SERVICE_NAME = 'youtubeAnalytics'

# %%
API_VERSION = 'v2'

# %%
def get_service():
    flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
    credentials = flow.run_console()
    return build(API_SERVICE_NAME, API_VERSION, credentials=credentials)

# %%
def execute_api_request(client_library_function, **kwargs):
    response = client_library_function(
        **kwargs
    ).execute()
    return response

# %%
ytanalytics = get_service()
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=448041969196-ak9e8atmdk31pnfa3tu5dph2884ik6ef.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyt-analytics.readonly&state=CSyNcAAt63y17vCIf5s7UJSKXe4hKh&prompt=consent&access_type=offline
# Enter the authorization code: 4/1AdQt8qhmQ29uVaqzQ6U9piX8U0Cq1eC8LSwwoIRjlLlJaPmE2OXHOgbbfzA

# %%
ytanalytics.reports().query
# Out:
# <bound method createMethod.<locals>.method of <googleapiclient.discovery.Resource object at 0x7fba594fff10>>

# %%
result = execute_api_request(
                    ytanalytics.reports().query,
                    ids='channel==MINE',
                    startDate='2020-01-01',
                    endDate='2022-02-02',
                    metrics='views,likes',
                    dimensions='gender')
# Out:
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-53-23f368a82f99> in <module>
# ----> 1 result = execute_api_request(
#       2                     ytanalytics.reports().query,
#       3                     ids='channel==MINE',
#       4                     startDate='2020-01-01',
#       5                     endDate='2022-02-02',
#
# <ipython-input-48-18dfa5bf14d4> in execute_api_request(client_library_function, **kwargs)
#       1 def execute_api_request(client_library_function, **kwargs):
# ----> 2     response = client_library_function(
#       3         **kwargs
#       4     ).execute()
#       5     return response
#
# ~/opt/anaconda3/lib/python3.8/site-packages/googleapiclient/_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
# ...

# %%
# !pip install tabulate
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.2 is available.
# You should consider upgrading via the '/Users/praneeth/opt/anaconda3/bin/python -m pip install --upgrade pip' command.

# %%
import os
from venv import create
from googleapiclient.discovery import build
from google_auth_oauthlib.flow import InstalledAppFlow

from tabulate import tabulate

SCOPES = ['https://www.googleapis.com/auth/yt-analytics.readonly']

API_SERVICE_NAME = 'youtubeAnalytics'
API_VERSION = 'v2'
# CLIENT_SECRETS_FILE = 'client_secret_desktop_temp.json'
CLIENT_SECRETS_FILE = 'client_secret_448041969196-ak9e8atmdk31pnfa3tu5dph2884ik6ef.apps.googleusercontent.com.json'

def get_service():
  flow = InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE, SCOPES)
  credentials = flow.run_console()
  return build(API_SERVICE_NAME, API_VERSION, credentials = credentials)

def execute_api_request(client_library_function, **kwargs):
  response = client_library_function(
    **kwargs
  ).execute()
  return response

def create_table(table, headers=None):
    if headers:
        headerstring = "\t{}\t" * len(headers)
        print(headerstring.format(*headers))

    rowstring = "\t{}\t" * len(table[0])

    for row in table:
        print(rowstring.format(*row))


if __name__ == '__main__':

    youtubeAnalytics = get_service()
    result = execute_api_request(
        youtubeAnalytics.reports().query,
        ids='channel==MINE',
        startDate='2022-01-01',
        endDate='2022-04-30',
        metrics='estimatedMinutesWatched,views,likes,subscribersGained,shares',
        dimensions='ageGroup',
        sort='ageGroup'
    )
    print(result)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=448041969196-ak9e8atmdk31pnfa3tu5dph2884ik6ef.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyt-analytics.readonly&state=QWoGyzu4KIl2IjzHoesdE5im5vSPzi&prompt=consent&access_type=offline
# Enter the authorization code: 4/1AdQt8qh__ebRsTFYJfDPVW3OE67gTlrvsqhszimL3VAQytcOjpVLwl2okEg
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# <ipython-input-32-cb614aaf96ae> in <module>
#      38
#      39     youtubeAnalytics = get_service()
# ---> 40     result = execute_api_request(
#      41         youtubeAnalytics.reports().query,
#      42         ids='channel==MINE',
#
# <ipython-input-32-cb614aaf96ae> in execute_api_request(client_library_function, **kwargs)
#      19
# ...

# %%
headers = ['date', 'estMinutesWatched', 'views', 'likes', 'subscribersGained', 'shares', 'country']
# create_table(result['rows'], headers=headers)
print(tabulate(result['rows'], headers=headers, tablefmt="pretty"))
# Out:
# +------+-------------------+-------+-------+-------------------+--------+---------+
# | date | estMinutesWatched | views | likes | subscribersGained | shares | country |
# +------+-------------------+-------+-------+-------------------+--------+---------+
# +------+-------------------+-------+-------+-------------------+--------+---------+
